# %%
# import libraries
import pandas as pd
import requests
import json
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import sys
import import_ipynb
import config
# Out:
# importing Jupyter notebook from config.ipynb

# %%
# importing the client keys
cid = config.cid
secret = config.secret

# setting up the spotify object
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# getting tracks data
track_id = []
artist_id = []
album_id = []
track_name = []
track_current_popularity = []
track_available_market = []


for i in range(0,1000,50):
    track_results = sp.search(q='year:2019',type='track', limit=50,offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        track_id.append(t['id'])
        artist_id.append(t['artists'][0]['id'])
        album_id.append(t['album']['id'])
        track_name.append(t['name'])
        track_current_popularity.append(t['popularity'])
        track_available_market.append(t['available_markets'])

# dictionary of tracks 
tracks_dict = {'track_id': track_id, 'artist_id': artist_id, 'album_id': album_id,
       'track_name': track_name, 'track_current_popularity': track_current_popularity, 'track_available_market': track_available_market} 
    
tracks_df = pd.DataFrame(dict)
    
tracks_df.head()
# Out:
#                  track_id               artist_id                album_id  \
# 0  2cNDSHY1MrR8YdxTIF2TXa  3Ejqnl3gjpM9iDwKni6EkF  0aQ1TtpbqxzMKpZloGvrGL
# 1  07X9ff6BnK9i0IoazB5NrO  2Lz82DKx39DuPNUG9JNnoO  1c65ZYuJZBahDtQCcHDqXi
# 2  4Y0LXxF0uitxc9mPIuyTsU  7FhayGedJ2SIiMdZy5owO0  6f4joKtmGZNblFm5QEBkkg
# 3  4fVC8Jec4JGpRQ5mzMV80a  3CZTF5XZZ3s9RS94kUcyLh  3hbOd0uV8qelJlgoUYXNO1
# 4  1K5SbcMQH7M1FImaEehuL2  0rAL7NwWli2ih71P4OlvIP  6CYyMIT7v3I8TX4dbqBIfb
#
#               track_name  track_current_popularity  \
# 0            Stone Ocean                         0
# 1  letter - Instrumental                         0
# 2              City life                         8
# 3              Let It Be                        15
# 4               Value Me                         4
#
#                               track_available_market
# 0  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
# 1  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
# ...

# %%
# getting tracks audio features
acousticness = []
danceability = []
energy = []
key = []
instrumentalness = []
liveness = []
loudness = []
speechiness = []
tempo = []
valence = []
duration_ms = []

for i in range(0,1000,50):

    features = sp.audio_features(track_id[i:i+50])
    
    for i, t in enumerate(features):

        try:
            acousticness.append(t['acousticness'])
        except:
            acousticness.append('')
            
        try:
            danceability.append(t['danceability'])
        except:
            danceability.append('')
        
        try:
            energy.append(t['energy'])
        except:
            energy.append('')
            
        try:
            key.append(t['key'])
        except:
            key.append('')
            
        try:
            instrumentalness.append(t['instrumentalness'])
        except:
            instrumentalness.append('')
            
        try:
            liveness.append(t['liveness'])
        except:
            liveness.append('')
            
        try:
            loudness.append(t['loudness'])
        except:
            loudness.append('')
            
        try:
            speechiness.append(t['speechiness'])
        except:
            speechiness.append('')
               
        try:
            tempo.append(t['tempo'])
        except:
            tempo.append('')
            
        try:
            valence.append(t['valence'])
        except:
            valence.append('')
            
        try:
            duration_ms.append(t['duration_ms'])
        except:
            duration_ms.append('')
        
# dictionary of audio_features 
audio_features_dict = {'track_id': track_id, 'acousticness': acousticness,
                       'danceability': danceability, 'energy': energy,
                       'key': key, 'instrumentalness': instrumentalness,
                       'liveness': liveness, 'loudness': loudness,
                       'speechiness': speechiness, 'tempo': tempo,
                       'valence': valence, 'duration_ms': duration_ms
                      } 

    
audio_features_df = pd.DataFrame(audio_features_dict)
    
audio_features_df.head()
# Out:
#                  track_id  acousticness  danceability  energy  key  \
# 0  25imbRT3svjKyjGqhCXekG        0.0116         0.799   0.669    7
# 1  5AFh2HFtUylbvnqRZnxFz0        0.0336         0.746   0.632    4
# 2  6fWG9iEt4PJxEVVQcY18WI        0.0482         0.774   0.529    5
# 3  15EeWguNeeIfuM9dEHdy6q        0.7020         0.580   0.781    0
# 4  23yjPJ2Pr0WDr7ciTI2Krd        0.0117         0.636   0.824    2
#
#    instrumentalness  liveness  loudness  speechiness    tempo  valence  \
# 0          0.883000    0.0904   -12.166       0.1880  127.037    0.459
# 1          0.000000    0.2300    -7.288       0.3000   93.940    0.605
# 2          0.902000    0.1220   -13.101       0.0619  100.670    0.395
# 3          0.000025    0.1380    -4.928       0.0679  108.837    0.321
# 4          0.171000    0.4710    -7.126       0.0823  166.075    0.391
#
#    duration_ms
# 0       489528
# 1       168020
# 2       192699
# 3       265719
# 4       157587

# %%
# getting tracks artist

artist_name = []
artist_popularity = []
artist_markets = []
artist_followers = []
artist_genres = []
artist_images = []


for i in range(0,1000,50):

    artist_results = sp.artists(artist_id[i:i+50])
    
    for artist in artist_results['artists']:

        artist_name.append(artist['name'])
        artist_popularity.append(artist['popularity'])
        artist_followers.append(artist['followers']['total'])
        artist_genres.append(artist['genres'])
        
        try:
            artist_images.append(artist['images'][0]['url'])
        except:
            artist_images.append('')

        

# dictionary of artist_results
artist_dict = {'artist_id': artist_id, 'artist_name': artist_name,
               'artist_popularity': artist_popularity, 'artist_followers': artist_followers,
               'artist_genres': artist_genres, 'artist_images': artist_images
              } 

    
artist_df = pd.DataFrame(artist_dict)
    
artist_df.head()
# Out:
#                 artist_id        artist_name  artist_popularity  \
# 0  1H5oJVp4ZFT1RxaCJ7V29x      Evelina Viola                  0
# 1  64Zevud6ZejXRQjAMhlZS8         Igor Roque                 50
# 2  1k54s9Eyt0oD70MxO9iRko              C.A.P                  3
# 3  46BOHxAIRQzHWjAjb8X6zi  ASMR Water Sounds                  1
# 4  6fUe2NjfQbI4yxIFBwYFg8          seeeeecun                 20
#
#    artist_followers    artist_genres  \
# 0               239               []
# 1             24035  [indie cristao]
# 2               987               []
# 3                75           [asmr]
# 4              5116               []
#
#                                        artist_images
# 0  https://i.scdn.co/image/ab67616d0000b2732fe822...
# 1  https://i.scdn.co/image/ab6761610000e5eb8ca5b3...
# 2  https://i.scdn.co/image/ab67616d0000b273c307be...
# 3  https://i.scdn.co/image/ab67616d0000b2731aab7e...
# 4  https://i.scdn.co/image/ab6761610000e5ebbbb884...

# %%
# getting artists data
artist_id = []
artist_name = []
artist_popularity = []
artist_markets = []
artist_followers = []
artist_genre = []
artist_images = []
count = 0
for i in range(0,1000,50):
    artists_results = sp.search(q='year:2023',type='track', limit=50, offset=i)
    for i, t in enumerate(artists_results['tracks']['items']):
        print(t['artists'])
        count += 1
        if count == 2:
            break
#         artist_name.append(t['artists'][0]['name'])
#         track_name.append(t['name'])
#         track_album.append(t['album']['name'])
#         track_id.append(t['id'])
#         popularity.append(t['popularity'])

    break
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0HpSX29rUOpxwfirNWB5PP'}, 'href': 'https://api.spotify.com/v1/artists/0HpSX29rUOpxwfirNWB5PP', 'id': '0HpSX29rUOpxwfirNWB5PP', 'name': 'Ivan Mercy', 'type': 'artist', 'uri': 'spotify:artist:0HpSX29rUOpxwfirNWB5PP'}]
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7MXzWeLsIPnP0k94VeHEpk'}, 'href': 'https://api.spotify.com/v1/artists/7MXzWeLsIPnP0k94VeHEpk', 'id': '7MXzWeLsIPnP0k94VeHEpk', 'name': 'EDM NATIVES', 'type': 'artist', 'uri': 'spotify:artist:7MXzWeLsIPnP0k94VeHEpk'}]

# %%
artist_name = []
track_name = []
popularity = []
track_id = []

birdy_uri = 'spotify:artist:2WX2uTcsvV5OnS0inACecP'

results = sp.artist_albums(birdy_uri, album_type='album')
albums = results['items']
while results['next']:
    results = spotify.next(results)
    albums.extend(results['items'])

for album in albums:
    print(album['name'])
# Out:
# Portraits (+ Remixes)
# Portraits
# Young Heart
# Beautiful Lies (Deluxe)
# Beautiful Lies
# Fire Within
# Live in London
# Birdy

# %%
# if len(sys.argv) > 1:
#     name = ' '.join(sys.argv[1:])
# else:
name = 'Taylor Swift'

results = sp.search(q='artist:' + name, type='artist')
items = results['artists']['items']
if len(items) > 0:
    artist = items[0]
    print(artist['name'], artist['images'][0]['url'])
# Out:
# Taylor Swift https://i.scdn.co/image/ab6761610000e5eb859e4c14fa59296c8649e0e4
